# %% [markdown]
# # 2. Übungsblatt DSAI

# %% [markdown]
# ## What are the basic summary statistics for each variable in the dataset bodyfat, such as mean,median, standard deviation, minimum, and maximum values?

# %%
import pandas as pd

data = pd.read_csv("datasets/bodyfat.csv")

data.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %% [markdown]
# ## Show boxplots and histograms of the attributs bodyfat, age, weight to find out how the data a distributed.

# %%
data["BodyFat"].plot(kind = 'hist',bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Age"].plot(kind = 'hist',bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Weight"].plot(kind = 'hist',bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["BodyFat"].plot.box()
# Out:
# <Axes: >

# %%
data["Age"].plot.box()
# Out:
# <Axes: >

# %%
data["Weight"].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ## Create the DataFrame (df votes) from the csv data on registered voters in the United States, including demographic information and political preference. Using pandas, print the first 5 rows of the DataFrame to get a sense of what the data looks like. Next, answer the following questions:

# %%
import pandas as pd

dt_votes = pd.read_csv("datasets/anes96.csv")

print(dt_votes[0:5])
# Out:
#    Unnamed: 0  popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  income  \
# 0           0    0.0     7.0     7.0     1.0     6.0  6.0  36.0   3.0     1.0
# 1           1  190.0     1.0     3.0     3.0     5.0  1.0  20.0   4.0     1.0
# 2           2   31.0     7.0     2.0     2.0     6.0  1.0  24.0   6.0     1.0
# 3           3   83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0     1.0
# 4           4  640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0     1.0
#
#    vote  logpopul
# 0   1.0 -2.302585
# 1   0.0  5.247550
# 2   0.0  3.437208
# 3   0.0  4.420045
# 4   0.0  6.461624

# %% [markdown]
# ## 3. How many observations are in the DataFrame?
# ## 4. How many variables are measured (how many columns)?

# %%
dt_votes.describe()
# Out:
#        Unnamed: 0        popul      TVnews      selfLR      ClinLR  \
# count  944.000000   944.000000  944.000000  944.000000  944.000000
# mean   471.500000   306.381356    3.727754    4.325212    2.939619
# std    272.653626  1082.606745    2.677235    1.438436    1.383725
# min      0.000000     0.000000    0.000000    1.000000    1.000000
# 25%    235.750000     1.000000    1.000000    3.000000    2.000000
# 50%    471.500000    22.000000    3.000000    4.000000    3.000000
# 75%    707.250000   110.000000    7.000000    6.000000    4.000000
# max    943.000000  7300.000000    7.000000    7.000000    7.000000
#
#            DoleLR         PID         age        educ      income        vote  \
# count  944.000000  944.000000  944.000000  944.000000  944.000000  944.000000
# mean     5.394068    2.842161   47.043432    4.565678   16.331568    0.416314
# std      1.269349    2.273337   16.423130    1.599287    5.974781    0.493208
# ...

# %% [markdown]
# ## 5. What is the age of the youngest person in the data? The oldest?
# Min Age: 19
#
# Max Age: 91

# %% [markdown]
# ## 6. How many days a week does the average respondent watch TV news (round to the nearest tenth)?
# Mean: 3.73

# %% [markdown]
# ## 7. Check for missing values. Are there any?

# %%
print(dt_votes.isna().sum())
print(dt_votes.isnull().sum())
# Out:
# Unnamed: 0    0
# popul         0
# TVnews        0
# selfLR        0
# ClinLR        0
# DoleLR        0
# PID           0
# age           0
# educ          0
# income        0
# vote          0
# logpopul      0
# dtype: int64
# Unnamed: 0    0
# popul         0
# TVnews        0
# selfLR        0
# ClinLR        0
# DoleLR        0
# PID           0
# age           0
# educ          0
# income        0
# vote          0
# logpopul      0
# dtype: int64

# %% [markdown]
# ## 8. Use the filtering method to find all the respondents who have the impression that Bill Clinton is moderate or conservative (ClinLR equals 4 or higher). How many respondents are in this subset?

# %%
print(dt_votes[dt_votes["ClinLR"] >= 4])
print(933 / 944)
# Out:
#      Unnamed: 0  popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  \
# 3             3   83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0
# 4             4  640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0
# 5             5  110.0     3.0     3.0     4.0     6.0  1.0  21.0   4.0
# 6             6  100.0     7.0     5.0     6.0     4.0  1.0  77.0   4.0
# 7             7   31.0     1.0     5.0     4.0     5.0  4.0  21.0   4.0
# ..          ...    ...     ...     ...     ...     ...  ...   ...   ...
# 911         911   24.0     7.0     3.0     4.0     5.0  1.0  38.0   7.0
# 912         912   18.0     0.0     2.0     4.0     6.0  1.0  51.0   7.0
# 921         921    0.0     7.0     2.0     4.0     5.0  2.0  53.0   6.0
# 925         925    0.0     0.0     3.0     4.0     4.0  0.0  48.0   6.0
# 933         933   27.0     7.0     4.0     4.0     7.0  2.0  46.0   3.0
#
#      income  vote  logpopul
# 3       1.0   0.0  4.420045
# 4       1.0   0.0  6.461624
# ...

# %% [markdown]
# ## 9. Among these respondents, how many have a household income less than $ 50,000 and attended at least some college?

# %%
print(dt_votes[(dt_votes["income"] < 20) & (dt_votes["educ"] >= 4)])
print(572 / 944)
# Out:
#      Unnamed: 0  popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  \
# 1             1  190.0     1.0     3.0     3.0     5.0  1.0  20.0   4.0
# 2             2   31.0     7.0     2.0     2.0     6.0  1.0  24.0   6.0
# 3             3   83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0
# 4             4  640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0
# 5             5  110.0     3.0     3.0     4.0     6.0  1.0  21.0   4.0
# ..          ...    ...     ...     ...     ...     ...  ...   ...   ...
# 566         566    0.0     4.0     4.0     2.0     5.0  4.0  35.0   7.0
# 568         568   71.0     2.0     4.0     6.0     2.0  0.0  57.0   4.0
# 570         570   83.0     4.0     1.0     4.0     6.0  2.0  43.0   6.0
# 571         571  360.0     3.0     4.0     4.0     7.0  0.0  34.0   4.0
# 572         572  180.0     7.0     2.0     2.0     4.0  0.0  44.0   5.0
#
#      income  vote  logpopul
# 1       1.0   0.0  5.247550
# 2       1.0   0.0  3.437208
# ...
