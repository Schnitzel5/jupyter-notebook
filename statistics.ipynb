# %% [markdown]
# # Statistics

# %% [markdown]
# ## Key Terms for Data Types
# ## Numeric
# Data that are expressed on a numeric scale.
# ### Continuous
# Data that can take on any value in an interval. (Synonyms: interval, float,
# numeric)
# ### Discrete
# Data that can take on only integer values, such as counts. (Synonyms: integer,
# count)
# ###  Categorical
# Data that can take on only a specific set of values representing a set of possible
# categories. (Synonyms: enums, enumerated, factors, nominal)
# ### Binary
# A special case of categorical data with just two categories of values, e.g., 0/1,
# true/false. (Synonyms: dichotomous, logical, indicator, boolean)
# Ordinal
# Categorical data that has an explicit ordering. (Synonym: ordered factor)

# %% [markdown]
# # Key Terms for Estimates of Location
# ## Mean
# The sum of all values divided by the number of values.
# Synonym
# average
# ## Weighted mean
# The sum of all values times a weight divided by the sum of the weights.
# Synonym
# weighted average
# ## Median
# The value such that one-half of the data lies above and below.
# Synonym
# ## 50th percentile
# Percentile
# The value such that P percent of the data lies below.
# Synonym
# quantile
# ## Weighted median
# The value such that one-half of the sum of the weights lies above and below the
# sorted data.
# ## Trimmed mean
# The average of all values after dropping a fixed number of extreme values.
# Synonym
# truncated mean
# ## Robust
# Not sensitive to extreme values.
# Synonym
# resistant
# ## Outlier
# A data value that is very different from most of the data.
# Synonym
# extreme value

# %% [markdown]
# # Key Terms for Variability Metrics
# ## Deviations
# The difference between the observed values and the estimate of location.
# Synonyms
# errors, residuals
# ##  Variance
# The sum of squared deviations from the mean divided by n – 1 where n is the
# number of data values.
# Synonym
# mean-squared-error
# ## Standard deviation
# The square root of the variance.
# ##  Mean absolute deviation
# The mean of the absolute values of the deviations from the mean.
# ## Range
# The difference between the largest and the smallest value in a data set.
# ## Order statistics
# Metrics based on the data values sorted from smallest to biggest.
# Synonym
# ranks
# ## Percentile
# The value such that P percent of the values take on this value or less and (100–P)
# percent take on this value or more.
# Synonym
# quantile
# ##  Interquartile range
# The difference between the 75th percentile and the 25th percentile.
# Synonym
# IQR

# %%
import pandas as pd

# %%
#data = pd.read_csv("c:/home/DSAI/datasets/bodyfat.csv");

# %% [markdown]
# ### Null Values?

# %%
data.isna()
data.isna().any()
print(data.isnull())
print(data.isnull().sum()) # Null values in rows
print(data.isnull().sum().sum()) # Sum of all null values
# Out:
#      Density  BodyFat    Age  Weight  Height   Neck  Chest  Abdomen    Hip  \
# 0      False    False  False   False   False  False  False    False  False
# 1      False    False  False   False   False  False  False    False  False
# 2      False    False  False   False   False  False  False    False  False
# 3      False    False  False   False   False  False  False    False  False
# 4      False    False  False   False   False  False  False    False  False
# ..       ...      ...    ...     ...     ...    ...    ...      ...    ...
# 247    False    False  False   False   False  False  False    False  False
# 248    False    False  False   False   False  False  False    False  False
# 249    False    False  False   False   False  False  False    False  False
# 250    False    False  False   False   False  False  False    False  False
# 251    False    False  False   False   False  False  False    False  False
#
#      Thigh   Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %% [markdown]
# ### Summary of statistical Values

# %%
data.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %% [markdown]
# ## Descriptive Statistical Functions

# %% [markdown]
# |Sr.No. | Function   | Description|
# |:----- |:----- |:-----|
# |1 	| count() | Number of non-null observations|
# |2 	| sum()   | Sum of values|
# |3 	| mean()  |	Mean of Values|
# |4 	| median() | Median of Values|
# |5 	| mode() |	Mode of values|
# |6 	| std() |	Standard Deviation of the Values|
# |7 	| min() |	Minimum Value|
# |8 	| max() 	|Maximum Value|
# |9  | abs() 	|Absolute Value|
# |10 | prod() |	Product of Values|
# |11 | cumsum() |	Cumulative Sum|
# |12 | cumprod() |	Cumulative Product|

# %% [markdown]
# ## Statistical functions

# %%
print(data["Density"].mean(), data["Weight"].mean()); 
print(data["BodyFat"].median(),data["Height"].var()); 
print(data["BodyFat"].quantile(0.5))
print(data[["BodyFat","Weight"]].quantile([0.05, 0.25, 0.5, 0.75, 0.95]))
# Out:
# 1.0555738095238094 178.92440476190475
# 19.2 13.416512521343192
# 19.2
#       BodyFat    Weight
# 0.05    6.055  136.3875
# 0.25   12.475  159.0000
# 0.50   19.200  176.5000
# 0.75   25.300  197.0000
# 0.95   32.600  225.6500

# %%
# data["BodyFat"].max()
data[data["BodyFat"] <=5]
data.loc[data["BodyFat"] <=5, "Weight"]  # only Weight Col for BodyFat < 5
# Out:
# 8      191.00
# 25     159.25
# 28     133.25
# 49     127.50
# 54     136.25
# 170    152.25
# 171    125.75
# 181    118.50
# Name: Weight, dtype: float64

# %% [markdown]
# # Key Terms for Exploring the Distribution
# ## Boxplot
# A plot introduced by Tukey as a quick way to visualize the distribution of data.
# Synonym
# box and whiskers plot
# ## Frequency table
# A tally of the count of numeric data values that fall into a set of intervals (bins).
# ## Histogram
# A plot of the frequency table with the bins on the x-axis and the count (or proportion)
# on the y-axis. While visually similar, bar charts should not be confused
# with histograms. See “Exploring Binary and Categorical Data” on page 27 for a
# discussion of the difference.
# ## Density plot
# A smoothed version of the histogram, often based on a kernel density estimate.

# %% [markdown]
# # Plotting with Python/
#
# - Matplotlib is an amazing visualization library in Python for 2D plots of arrays
# - Pandas plotting is based on Matplotlib

# %%
# "matplotlib notebook" -- will lead to interactive plots embedded within the notebook
# "matplotlib inline" will lead to static images of your plot embedded in the notebook

# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background') # using a plotting style
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Plotting functions

# %%
def f(t):
    s1 = np.cos(2*np.pi*t)
    e1 = 5*np.exp(-t)
    return s1 * e1

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
t3 = np.arange(0.0, 5.0, 0.01)


fig, axs = plt.subplots(3, 1, figsize=(12, 10)) #constrained_layout=True)
plt.subplots_adjust(hspace=0.5)
axs[0].plot(t1, f(t1), 'o', t2, f(t2), '-')
axs[0].set_title('subplot 1')
axs[0].set_xlabel('distance (m)',fontsize=10)
axs[0].set_ylabel('Damped oscillation')
fig.suptitle('This is a somewhat long figure title', fontsize=16)

axs[1].plot(t2, np.cos(2*np.pi*t2), '--')
axs[1].set_xlabel('time (s)')
axs[1].set_title('subplot 2',fontsize=12)
axs[1].set_ylabel('Undamped')

axs[2].plot(t3, 3*np.sin(2*np.pi*t3)*np.cos(2*t3), '-')
axs[2].set_xlabel('time (s)')
axs[2].set_title('subplot 3')
axs[2].set_ylabel('SinCos')

plt.show()

# %% [markdown]
# ## Plotting Series

# %%
#data.plot() # plots "full" datafrae 
(data["Height"]*2.54).plot(linestyle=":", linewidth=5)
plt.xlabel("Subjects", fontname="Brush Script MT", fontsize=18) 
plt.ylabel("Height in m", fontname="Brush Script MT", fontsize=18) 
plt.show()

# %% [markdown]
# ### Figure class

# %%
fig, ax = plt.subplots(figsize=(10, 5), facecolor='lightgrey',
                       layout='compressed')  # or e.g. compressed or constrained
fig.suptitle('Figure',color="black")
ax.set_title('Axes', loc='left', fontstyle='oblique', fontsize='medium', color="black")
# Out:
# Text(0.0, 1.0, 'Axes')

# %% [markdown]
# ## Colors

# %%
import matplotlib.colors as mcolors
#plot_colortable(mcolors.CSS4_COLORS)
#plt.show()
import math

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
#plot_colortable(mcolors.CSS4_COLORS)
plt.show()
mcolors.TABLEAU_COLORS
# Out:
# {'tab:blue': '#1f77b4',
#  'tab:orange': '#ff7f0e',
#  'tab:green': '#2ca02c',
#  'tab:red': '#d62728',
#  'tab:purple': '#9467bd',
#  'tab:brown': '#8c564b',
#  'tab:pink': '#e377c2',
#  'tab:gray': '#7f7f7f',
#  'tab:olive': '#bcbd22',
#  'tab:cyan': '#17becf'}

# %% [markdown]
# ## Histogram

# %%
#ax = data["BodyFat"].plot(kind ='hist',bins=8)

#ax = plt.subplots()
#data["BodyFat"].plot.hist(bins=20,color = "slategrey",ec="white") # or 

#plt.figure()
data["BodyFat"].plot.hist(bins=5,color = "slategrey",ec="white",alpha=0.6, label ='BodyFat1')

data["BodyFat"].hist(bins=20,color = "slategrey",ec="white",alpha=0.6, label ='BodyFat1')
data["BodyFat"].diff().hist(bins=20,color = "slategrey",ec="white",alpha=0.8, label ='BodyFat2');  # diff() returns differences between data rows
plt.legend();
plt.show()


data[["Neck","Chest","Hip","Biceps"]].hist(bins=20,color = "grey")
plt.show()

# %% [markdown]
# ## Boxplot

# %%
#Simple Boxplot
plt.style.use('seaborn-v0_8-darkgrid')
plt.boxplot(data["BodyFat"], patch_artist=True,
            # Set facecolor to red
            boxprops=dict(facecolor='grey'))
plt.title('BodyFat')
plt.ylabel('BF in %')
plt.show()

# %% [markdown]
# #### Pandas "Style"

# %%
data["BodyFat"].plot.box(widths=5,color="g")
plt.show()

ax = data["Age"].plot.box(figsize=(5, 3))


c = 'b'
# Create dictionary of keyword aruments to pass to plt.boxplot
red_dict =  {'patch_artist': True,
             'boxprops': dict(color=c, facecolor=c),
             'capprops': dict(color=c),
             'flierprops': dict(color=c, markeredgecolor=c),
             'medianprops': dict(color=c),
             'whiskerprops': dict(color=c)}
# Pass dictionary to boxplot using ** operator to unpack it
#data["BodyFat"].plot.box(**red_dict)
plt.show()

# %%
data[["Age","Neck"]].plot.box(color="grey")
data[["Neck","Chest","Hip","Biceps"]].plot.box(vert=False, showmeans=True, showfliers=True, positions=[1, 2, 5, 6]);

# %%
data[["Neck","Chest","Hip","Biceps"]].plot.box(positions=[1, 2, 4,5], widths=1.5, patch_artist=True,
                showmeans=True, showfliers=False,
                medianprops={"color": "black", "linewidth": 1.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "pink", "linewidth": 1.5},
                capprops={"color": "lime", "linewidth": 1.5},
                notch=True)
# Out:
# <Axes: >

# %%
import os
os.getcwd() # get working directory

#%run "C://Users/pauli/PandasIntro.ipynb"
#from PandasIntro.ipynb import airdelay
air1 = pd.read_csv("c:/home/DSAI/datasets/airlinesdeley.csv")
air2 = pd.read_csv("c:/home/DSAI/datasets/airlinesdeley1.csv")

flights = pd.merge(air1, air2, on='carrier')
flights.head()
# Out:
#    arr_delay carrier                   name
# 0       11.0      UA  United Air Lines Inc.
# 1       20.0      UA  United Air Lines Inc.
# 2       12.0      UA  United Air Lines Inc.
# 3        7.0      UA  United Air Lines Inc.
# 4      -14.0      UA  United Air Lines Inc.

# %%
# Make a separate list for each airline
x1 = list(flights[flights['name'] == 'United Air Lines Inc.']['arr_delay'])
x2 = list(flights[flights['name'] == 'JetBlue Airways']['arr_delay'])
x3 = list(flights[flights['name'] == 'ExpressJet Airlines Inc.']['arr_delay'])
x4 = list(flights[flights['name'] == 'Delta Air Lines Inc.']['arr_delay'])
x5 = list(flights[flights['name'] == 'American Airlines Inc.']['arr_delay'])

# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9', '#F0E442', '#009E73', '#D55E00']
names = ['United Air Lines Inc.', 'JetBlue Airways', 'ExpressJet Airlines Inc.', 'Delta Air Lines Inc.', 'American Airlines Inc.']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3, x4, x5], bins = int(180/15), color = colors, label=names) #,normed=True

# Plot formatting
plt.legend()
plt.xlabel('Delay (min)')
plt.ylabel('Normalized Flights')
plt.title('Side-by-Side Histogram with Multiple Airlines')
# Out:
# Text(0.5, 1.0, 'Side-by-Side Histogram with Multiple Airlines')

# %%
 
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data[["Neck","Chest","Hip","Biceps"]], patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#0000FF', '#00FF00', 
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['Neck', 'Chest', 
                    'Hip', 'Biceps'])
 
# Adding title 
plt.title("BodyFat")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %% [markdown]
# ## Correlation Plots

# %% [markdown]
# - A metric that measures the extent to which numeric variables are associated with one another (ranges from –1 to +1).
# $
# r = \frac{{}\sum_{i=1}^{n} (x_i - \overline{x})(y_i - \overline{y})}
# {\sqrt{\sum_{i=1}^{n} (x_i - \overline{x})^2  \sum_{i=1}^{n}(y_i - \overline{y})^2}}
# $

# %%
data.corr()
dataorderd = data.corr().abs().unstack()
dataorderd.sort_values(ascending=False)
#print(dataorderd.to_string())
#print(dataorderd.sort_values(ascending=False).to_string())
# Out:
# Density  Density    1.000000
# BodyFat  BodyFat    1.000000
# Forearm  Forearm    1.000000
# Biceps   Biceps     1.000000
# Ankle    Ankle      1.000000
#                       ...
# Age      Biceps     0.041162
#          Knee       0.017516
# Knee     Age        0.017516
# Weight   Age        0.012746
# Age      Weight     0.012746
# Length: 225, dtype: float64

# %%
plt.scatter(data["Weight"], data["BodyFat"])
plt.xlabel("Body Weight (lbs)")
plt.ylabel("Percent Body Fat")

plt.show()

# %%
data.plot.scatter(x="Wrist", y="BodyFat", alpha=1)
data.plot.scatter(x="Knee", y="BodyFat", alpha=0.5)
data.plot.scatter(x="Knee",y="Weight",marker='x')

plt.show()

# %%
import matplotlib as plt
import numpy as np

databf = data;

databf["BMI"] = 703*databf["Weight"]/(databf["Height"])**2

outliner = 35
x = databf.loc[databf["BMI"] < outliner,"BMI"]
y = databf.loc[databf["BMI"] < outliner,"BodyFat"]

plt.pyplot.scatter(x,y) 
plt.pyplot.title("BMI vrs Bodyfat")
plt.pyplot.ylabel('Bodyfat')
plt.pyplot.xlabel('BMI')

# adding linear regression line
lineStart = x.min()
lineEnd = x.max()
m, b = np.polyfit(x, y, 1)
plt.pyplot.plot(x, m*x+b, 'k-', color = 'b')

#plt.pyplot([lineStart, lineEnd], [lineStart, lineEnd], 'k-', color = 'r')
#plt.pyplot.plot([18, 34], [18, 34], 'k-', color = 'b')
plt.pyplot.show()

# %%
plt.figure
ax1 = data.plot.scatter(x="Weight", y="BodyFat", color="DarkBlue", label="Group 1")
data.plot.scatter(x="Age", y="BodyFat", color="DarkGreen", label="Group 2",ax = ax1)
# Out:
# <Axes: xlabel='Age', ylabel='BodyFat'>

# %% [markdown]
# ## Pie Charts

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
 
 
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD', 
        'TESLA', 'JAGUAR', 'MERCEDES']
 
data = [23, 17, 35, 29, 12, 41]
 
 
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
 
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige")
 
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
 
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
# Creating plot
fig, ax = plt.subplots(figsize =(6, 3))
wedges, texts, autotexts = ax.pie(data, 
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode, 
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
 
# Adding legend
ax.legend(wedges, cars,
          title ="Cars",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Customizing pie chart")
 
# show plot
plt.show()

# %% [markdown]
# ## Timeseries Plots

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# Plot the data with Matplotlib defaults + nicer style
plt.style.use("ggplot")
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %% [markdown]
# # Seaborn
# - Seaborn is a Python data visualization library and provides an user-friendly API on top of Matplotlib that offers sane choices for plot style and color defaults, etc# Seaborn

# %% [markdown]
# ### Density Plots

# %%
import seaborn as sns
sns.set_theme()
# Equivalent to:
#sns.set_style("darkgrid")


sns.displot(databf, x="BodyFat", kind="kde")
#sns.displot(databf, x="BodyFat", kind="kde", bw_adjust=.25) # smoothing bandwith parameter

# %%
#fig, ax = plt.subplots()
sns.displot(flights, x="arr_delay", hue="name", kind="kde",fill=False) # hue:  Comparison for each level
#ax.set_xlim(-200,200)
plt.ylim(0,0.005)
plt.xlim(-100, 100)
plt.show()

# %%
# Density Plot and Histogram of all arrival delays
sns.displot(databf, x="BodyFat", kde=True)
          #  bins=int(180/5), color = 'darkblue', 
           #  hist_kws={'edgecolor':'black,bw_adjust=.25'},
           #  kde_kws={'linewidth': 4})

# %%
import seaborn.objects as so
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

p = so.Plot(penguins, x="flipper_length_mm")
p.add(so.Area(), so.KDE())

# %%
p2 = p.add(so.Bars(alpha=.9), so.Hist("density",bins=50))
p2.add(so.Line(color='red'), so.KDE())

# %% [markdown]
# ## Empirical cumulative distributions

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind="ecdf")

# %% [markdown]
# ## Pair plots
# - Are very useful for exploring correlations between multidimensional data, when you'd like to plot all pairs of values against each other.

# %%
iris = sns.load_dataset("iris")    # Classical R dataset
iris.head()
sns.pairplot(iris, hue="species", height=2.5);

# %%
print(databf.head())
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist        BMI
# 0  37.3   21.9    32.0     27.4   17.1  23.624460
# 1  37.3   23.4    30.5     28.9   18.2  23.332048
# 2  38.9   24.0    28.8     25.2   16.6  24.666315
# 3  37.3   22.8    32.4     29.4   18.2  24.880784
# 4  42.2   24.0    32.2     27.7   17.7  25.514854

# %%
for index,i in enumerate(databf.columns):
    print(index,i)
# Out:
# 0 Density
# 1 BodyFat
# 2 Age
# 3 Weight
# 4 Height
# 5 Neck
# 6 Chest
# 7 Abdomen
# 8 Hip
# 9 Thigh
# 10 Knee
# 11 Ankle
# 12 Biceps
# 13 Forearm
# 14 Wrist
# 15 BMI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
import scipy.stats as stats
#plt.style.use('fivethirtyeight')
plt.style.use('ggplot')
colors=['#ffcd94','#eac086','#ffad60','#ffe39f']
sns.set_palette(sns.color_palette(colors))
#warnings.filterwarnings('ignore')

fig,ax = plt.subplots(16,3,figsize=(20,60))
for index,i in enumerate(databf.columns):
    sns.distplot(databf[i],ax=ax[index,0])
    sns.boxplot(databf[i],ax=ax[index,1])
    stats.probplot(databf[i],plot=ax[index,2])

#fig.tight_laprobplott()
fig.subplots_adjust(top=0.95)
plt.suptitle("Visualizing Continuous Columns",fontsize=50)
# Out:
# Text(0.5, 0.98, 'Visualizing Continuous Columns')

# %%
print(f'-------Column Skewness------\n{databf.skew(axis=0).sort_values()}')
# Out:
# -------Column Skewness------
# Height     -5.384987
# Forearm    -0.219333
# Density    -0.020176
# BodyFat     0.146353
# Wrist       0.281614
# Age         0.283521
# Biceps      0.285530
# Knee        0.516744
# Neck        0.552620
# Chest       0.681556
# Thigh       0.821210
# Abdomen     0.838418
# Weight      1.205263
# Hip         1.497127
# Ankle       2.255134
# BMI        12.592566
# dtype: float64

# %% [markdown]
# ### Heatmap

# %%
plt.style.use('ggplot') # using a plotting style
plt.figure(figsize=(10,10))
sns.heatmap(databf.corr(),annot=True,linewidth=0.3,fmt="0.2f")
# Out:
# <Axes: >

# %%
X = databf.drop(['BodyFat','Density'],axis=1)
y = databf['Density']

X['Bmi']=703*X['Weight']/(X['Height']*X['Height'])
X['ACratio'] = X['Abdomen']/X['Chest']
X['HTratio'] = X['Hip']/X['Thigh']
X.drop(['Weight','Height','Abdomen','Chest','Hip','Thigh'],axis=1,inplace=True)
X.head()
# Out:
#    Age  Neck  Knee  Ankle  Biceps  Forearm  Wrist        BMI        Bmi  \
# 0   23  36.2  37.3   21.9    32.0     27.4   17.1  23.624460  23.624460
# 1   22  38.5  37.3   23.4    30.5     28.9   18.2  23.332048  23.332048
# 2   22  34.0  38.9   24.0    28.8     25.2   16.6  24.666315  24.666315
# 3   26  37.4  37.3   22.8    32.4     29.4   18.2  24.880784  24.880784
# 4   24  34.4  42.2   24.0    32.2     27.7   17.7  25.514854  25.514854
#
#     ACratio   HTratio
# 0  0.915145  1.601695
# 1  0.886752  1.681431
# 2  0.917537  1.664430
# 3  0.848723  1.683860
# 4  1.027749  1.612342

# %%
np.abs(stats.zscore(X))
# Out:
#           Age      Neck      Knee     Ankle    Biceps   Forearm     Wrist  \
# 0    1.740073  0.738665  0.536131  0.710826  0.090676  0.626718  1.212541
# 1    1.819583  0.209365  0.536131  0.175947  0.588143  0.117079  0.031943
# 2    1.819583  1.645475  0.128592  0.530656  1.151940  1.717621  1.749177
# 3    1.501543  0.244041  0.536131  0.178762  0.041982  0.365012  0.031943
# 4    1.660563  1.480601  1.499585  0.530656  0.024347  0.477959  0.568578
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  1.996904  1.274507  1.574763  0.947298  2.213203  1.469689  0.290039
# 248  2.155924  1.198613  0.917952  0.057711  0.970588  0.031680  2.007273
# 249  2.155924  0.374239  0.536131  0.947298  0.322827  0.725891  0.246597
# 250  2.155924  0.374239  1.250314  0.237880  0.588143  0.365012  1.685292
# 251  2.314944  1.157394  1.499585  0.885365  0.473120  0.662531  2.865890
#
#           BMI       Bmi   ACratio   HTratio
# ...
